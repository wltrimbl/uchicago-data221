# %%
# This notebook plays with the MNIST digits dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from keras.datasets import mnist
(images, labels), (testX, testY) = mnist.load_data()

images = np.array(images).astype("float").reshape(-1,784) / 255
labels = np.array(labels)
X = images
Y = labels
testX = np.array(testX).astype("float").reshape(-1, 784) / 255
testY= np.array(testY)
print( images.shape, labels.shape, testX.shape, testY.shape) 
testX.shape, testY.shape, X.shape, Y.shape
# Out:
# (60000, 784) (60000,) (10000, 784) (10000,)
# ((10000, 784), (10000,), (60000, 784), (60000,))

# %%
digits = labels

# %%
digits[0:20]
# Out:
# array([5, 0, 4, 1, 9, 2, 1, 3, 1, 4, 3, 5, 3, 6, 1, 7, 2, 8, 6, 9],
#       dtype=uint8)

# %%
digits = np.array(images)

# %%
digits.shape
# Out:
# (60000, 784)

# %%
p = np.reshape(digits, newshape=( 60000, 28,28))

# %%
p.shape
# Out:
# (60000, 28, 28)

# %%
plt.imshow(p[4,::])

# %%
plt.subplot(221)
plt.imshow(p[0,::])
plt.subplot(222)
plt.imshow(p[1,::])
plt.subplot(223)
plt.imshow(p[2,::])
plt.subplot(224)
plt.imshow(p[3,::])
plt.savefig("MNIST.png", dpi=300, bbox_inches="tight")

# %%
for i in range(10):
    plt.subplot(3,4,i+1)
    plt.imshow(avgdigit[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 for i in range(10):
#       2     plt.subplot(3,4,i+1)
# ----> 3     plt.imshow(avgdigit[i])
#
# NameError: name 'avgdigit' is not defined

# %%
sample = digits[0:1000,:]

# %%
import seaborn as sb
sb.heatmap(sample)
plt.xlabel("pixels")
plt.ylabel("samples")
# Out:
# Text(50.722222222222214, 0.5, 'samples')

# %%
# Wait, this isn't quite what I want.  I want to reorder columns (pixel positions) and rows (sample digits).
sb.clustermap(sample)
# Out:
# /Users/wltrimbl/miniconda3/envs/tf/lib/python3.10/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
# A little busy, maybe only look at 100 samples?
sb.clustermap(sample[0:100,:])

# %%
sb.clustermap(sample[0:100,:], row_colors=labels[0:100])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/seaborn/matrix.py:52, in _convert_colors(colors)
#      51 try:
# ---> 52     to_rgb(colors[0])
#      53     # If this works, there is only one level of colors
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/matplotlib/colors.py:496, in to_rgb(c)
#     495 """Convert *c* to an RGB color, silently dropping the alpha channel."""
# --> 496 return to_rgba(c)[:3]
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/matplotlib/colors.py:299, in to_rgba(c, alpha)
#     298 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 299     rgba = _to_rgba_no_colorcycle(c, alpha)
#     300     try:
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/matplotlib/colors.py:381, in _to_rgba_no_colorcycle(c, alpha)
#     380 if not np.iterable(c):
# --> 381     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     382 if len(c) not in [3, 4]:
#
# ValueError: Invalid RGBA argument: 5
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 sb.clustermap(sample[0:100,:], row_colors=labels[0:100])
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/seaborn/matrix.py:1252, in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1249 if _no_scipy:
#    1250     raise RuntimeError("clustermap requires scipy to be available")
# -> 1252 plotter = ClusterGrid(data, pivot_kws=pivot_kws, figsize=figsize,
#    1253                       row_colors=row_colors, col_colors=col_colors,
#    1254                       z_score=z_score, standard_scale=standard_scale,
#    1255                       mask=mask, dendrogram_ratio=dendrogram_ratio,
#    1256                       colors_ratio=colors_ratio, cbar_pos=cbar_pos)
#    1258 return plotter.plot(metric=metric, method=method,
#    1259                     colorbar_kws=cbar_kws,
#    1260                     row_cluster=row_cluster, col_cluster=col_cluster,
#    1261                     row_linkage=row_linkage, col_linkage=col_linkage,
#    1262                     tree_kws=tree_kws, **kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/seaborn/matrix.py:718, in ClusterGrid.__init__(self, data, pivot_kws, z_score, standard_scale, figsize, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos)
#     713 self.mask = _matrix_mask(self.data2d, mask)
#     715 self._figure = plt.figure(figsize=figsize)
#     717 self.row_colors, self.row_color_labels = \
# --> 718     self._preprocess_colors(data, row_colors, axis=0)
#     719 self.col_colors, self.col_color_labels = \
#     720     self._preprocess_colors(data, col_colors, axis=1)
#     722 try:
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/seaborn/matrix.py:812, in ClusterGrid._preprocess_colors(self, data, colors, axis)
#     809                 labels = [colors.name]
#     810             colors = colors.values
# --> 812     colors = _convert_colors(colors)
#     814 return colors, labels
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/seaborn/matrix.py:57, in _convert_colors(colors)
#      54     return list(map(to_rgb, colors))
#      55 except ValueError:
#      56     # If we get here, we have nested lists
# ---> 57     return [list(map(to_rgb, l)) for l in colors]
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/seaborn/matrix.py:57, in <listcomp>(.0)
#      54     return list(map(to_rgb, colors))
#      55 except ValueError:
#      56     # If we get here, we have nested lists
# ---> 57     return [list(map(to_rgb, l)) for l in colors]
#
# TypeError: 'numpy.uint8' object is not iterable

# %%
# sb.clustermap wants a list of color names for row_colors.  Fine.  

h = {0: "black", 1:"brown", 2:"red", 3:"orange", 4:"yellow",
    5:"green", 6:"blue", 7:"purple", 8:"grey", 9:"white"}
colorlabels100 = []
for l in labels[0:100]:
    colorlabels100.append(h[l])
colorlabels100
# Out:
# ['green',
#  'black',
#  'yellow',
#  'brown',
#  'white',
#  'red',
#  'brown',
#  'orange',
#  'brown',
#  'yellow',
#  'orange',
#  'green',
#  'orange',
#  'blue',
#  'brown',
#  'purple',
#  'red',
#  'grey',
#  'blue',
#  'white',
#  'yellow',
#  'black',
#  'white',
#  'brown',
#  'brown',
#  'red',
#  'yellow',
#  'orange',
#  'red',
#  'purple',
#  'orange',
#  'grey',
#  'blue',
#  'white',
#  'black',
#  'green',
#  'blue',
#  'black',
#  'purple',
#  'blue',
#  'brown',
#  'grey',
#  'purple',
#  'white',
#  'orange',
#  'white',
#  'grey',
#  'green',
#  'white',
#  'orange',
#  'orange',
#  'black',
#  'purple',
#  'yellow',
#  'white',
#  'grey',
#  'black',
#  'white',
#  'yellow',
#  'brown',
#  'yellow',
#  'yellow',
#  'blue',
#  'black',
#  'yellow',
#  'green',
#  'blue',
#  'brown',
#  'black',
#  'black',
#  'brown',
#  'purple',
#  'brown',
#  'blue',
#  'orange',
#  'black',
#  'red',
#  'brown',
#  'brown',
#  'purple',
#  'white',
#  'black',
#  'red',
#  'blue',
#  'purple',
#  'grey',
#  'orange',
#  'white',
#  'black',
#  'yellow',
#  'blue',
#  'purple',
#  'yellow',
#  'blue',
#  'grey',
#  'black',
#  'purple',
#  'grey',
#  'orange',
#  'brown']

# %%
clustermap = sb.clustermap(sample[0:100,:], row_colors=colorlabels100)

# %%
# The clustermap library function gives me the data in attributes of the return value:
dir(clustermap)

# %%
# There is data, which is what I gave it, 
plt.imshow(clustermap.data)

# %%
# And data2d, which has been reordered
plt.imshow(clustermap.data2d, aspect="auto")

# %%
# I can plot what all the digits look like on top of each other
plt.imshow(np.array(clustermap.data.sum(axis=0)).reshape( (28,28)))

# %%
# And it turns out the indexes for the row- and column- reordering are buried in ax_col_dendrogram:
dir(clustermap.ax_col_dendrogram)

# %%
# To get the reordering of the rows and columns,
# https://github.com/mwaskom/seaborn/issues/1207
# I need clustermap.dendrogram_row.reordered_ind
clustermap.dendrogram_row.reordered_ind [ 0:20]
# Out:
# [28, 60, 68, 80, 25, 82, 56, 88, 34, 37, 69, 75, 81, 95, 1, 21, 51, 63, 64, 2]

# %%
clustermap.dendrogram_col.reordered_ind[0:10]
# Out:
# [352, 325, 353, 436, 435, 407, 380, 408, 547, 574]

# %%
digits.shape
# Out:
# (60000, 784)

# %%
# So let's get some pieces of this clustergram and plot them on a 28x28 pixel grid:
middlepixels = clustermap.dendrogram_col.reordered_ind[300:600]
endpixels = clustermap.dendrogram_col.reordered_ind[723:]

# %%
middle_image = np.zeros((28,28))
end_image = np.zeros((28,28))

# %%
middle_image.reshape((784,))[middlepixels] = 1
end_image.reshape((784,))[endpixels] = 1

# %%
# These are the pixels that were clustered
plt.subplot(121)
plt.imshow(middle_image)
plt.subplot(122)
plt.imshow(end_image)

# %%
# Asking clustermap to compare my rows and columns...
# Let us try PCA, linear-algebra-only dimension reduction approach.

from sklearn.decomposition import PCA
pca=PCA(n_components=30)
pca.fit(sample.T)
# Out:
# PCA(n_components=30)

# %%
pca.components_.shape
# Out:
# (30, 1000)

# %%
plt.scatter(pca.components_[0,:], pca.components_[1,:])

# %%
# This is a sample of 1000 points. 
h = {0: "black", 1:"brown", 2:"red", 3:"orange", 4:"yellow",
    5:"green", 6:"blue", 7:"purple", 8:"grey", 9:"white"}
colorlabels1k = []
for l in labels[0:1000]:
    colorlabels1k.append(h[l])
colorlabels1k[0:50]

colorlabelsall = []
for l in labels:
    colorlabelsall.append(h[l])
colorlabelsall[0:5]
# Out:
# ['green', 'black', 'yellow', 'brown', 'white']

# %%
dir(pca)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_check_feature_names',
#  '_check_n_features',
#  '_fit',
#  '_fit_full',
#  '_fit_svd_solver',
#  '_fit_truncated',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_n_features_out',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_sklearn_auto_wrap_output_keys',
#  '_validate_data',
#  '_validate_params',
#  'components_',
#  'copy',
#  'explained_variance_',
#  'explained_variance_ratio_',
#  'fit',
#  'fit_transform',
#  'get_covariance',
#  'get_feature_names_out',
#  'get_params',
#  'get_precision',
#  'inverse_transform',
#  'iterated_power',
#  'mean_',
#  'n_components',
#  'n_components_',
#  'n_features_',
#  'n_features_in_',
#  'n_oversamples',
#  'n_samples_',
#  'noise_variance_',
#  'power_iteration_normalizer',
#  'random_state',
#  'score',
#  'score_samples',
#  'set_output',
#  'set_params',
#  'singular_values_',
#  'svd_solver',
#  'tol',
#  'transform',
#  'whiten']

# %%
plt.scatter(pca.components_[0,:], pca.components_[1,:], color=colorlabels1k)
plt.xlabel("PC0 {:.2f}%".format(pca.explained_variance_ratio_[0]*100))
plt.ylabel("PC1 {:.2f}%".format(pca.explained_variance_ratio_[1]*100))
# Out:
# Text(0, 0.5, 'PC1 6.11%')

# %%
plt.scatter(pca.components_[0,:], pca.components_[1,:], color=colorlabels1k)
plt.xlabel("PC 1    "+"{:.1f}".format(pca.explained_variance_ratio_[0] * 100) + "%"); 
plt.ylabel("PC 2    "+"{:.1f}".format(pca.explained_variance_ratio_[1] * 100) + "%");

# %%
plt.scatter(pca.components_[2,:], pca.components_[3,:], color=colorlabels1k)
plt.xlabel("PC 3    "+"{:.1f}".format(pca.explained_variance_ratio_[2] * 100) + "%"); 
plt.ylabel("PC 4    "+"{:.1f}".format(pca.explained_variance_ratio_[3] * 100) + "%");

# %%
# A little disappointing, 1000 digits fed into PCA and plotted. 
# Let us try TSNE on this 1000 sample by 30-dimensional PCA

# %%
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2, learning_rate=.1, init='random').fit(pca.components_.T)

# %%
X_embedded
# Out:
# TSNE(init='random', learning_rate=0.1)

# %%
dir(X_embedded)
# Out:
# ['_EXPLORATION_N_ITER',
#  '_N_ITER_CHECK',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_feature_names',
#  '_check_n_features',
#  '_check_params_vs_input',
#  '_fit',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_tsne',
#  '_validate_data',
#  '_validate_params',
#  'angle',
#  'early_exaggeration',
#  'embedding_',
#  'fit',
#  'fit_transform',
#  'get_params',
#  'init',
#  'kl_divergence_',
#  'learning_rate',
#  'learning_rate_',
#  'method',
#  'metric',
#  'metric_params',
#  'min_grad_norm',
#  'n_components',
#  'n_features_in_',
#  'n_iter',
#  'n_iter_',
#  'n_iter_without_progress',
#  'n_jobs',
#  'perplexity',
#  'random_state',
#  'set_params',
#  'square_distances',
#  'verbose']

# %%
X_embedded.embedding_.shape
# Out:
# (1000, 2)

# %%
# We want to plot embedding_[:,1] against embedding_[:,0] 
plt.scatter(X_embedded.embedding_[:,0], X_embedded.embedding_[:,1])

# %%
# And add label colors
plt.scatter(X_embedded.embedding_[:,0], X_embedded.embedding_[:,1], color=colorlabels1k)

# %%
# This is a little more satisfying than [blind] PCA, but 
# less than perfect.

# %%
# Fit 50-component PCA on all the data
pca50=PCA(n_components=50)
pca50.fit(digits.T)
# Out:
# PCA(n_components=50)

# %%
plt.scatter(pca50.components_[0,:], pca50.components_[1,:], color=colorlabelsall)
plt.xlabel("PC 1    "+"{:.1f}".format(pca50.explained_variance_ratio_[0] * 100) + "%"); 
plt.ylabel("PC 2    "+"{:.1f}".format(pca50.explained_variance_ratio_[1] * 100) + "%");

# %%
pca50.components_.shape
# Out:
# (50, 60000)

# %%
# Fit TSNE on subset of the big PCA output, but since TSNE takes too long for 10^{4} points, use only 
# 1000 samples
TSNE1K = TSNE(n_components=2, learning_rate=.1, init='random').fit(pca50.components_[:,0:1000].T)

# %%
plt.scatter(TSNE1K.embedding_[:,0], TSNE1K.embedding_[:,1], color=colorlabelsall[0:1000])

# %%
TSNE4K = TSNE(n_components=2, learning_rate=.1, init='random').fit(pca50.components_[:,0:4000].T)

# %%
plt.scatter(TSNE4K.embedding_[:,0], TSNE4K.embedding_[:,1], color=colorlabelsall[0:4000])

# %%
# Wait, this is qualitatively different from TSNE with n=1k 

# We can see that the TSNE procedure for drawing pretty 2d pictures that 
# reflect concentrations of point density in high dimensional spaces
# is sensitive to number of points and tuning parameters; 
# and be warned, it is not deterministic, so you don't get the
# same clouds each time you run it.  But it sure is pretty.

# %%
TSNE10K = TSNE(n_components=2, learning_rate=1.5, init="random").fit(pca50.components_[:,0:10000].T)

# %%
plt.scatter(TSNE10K.embedding_[:,0], TSNE10K.embedding_[:,1], color=colorlabelsall[0:10000])

# %%
digits

# %%
# The image of all the pixels flattened out is jumbled -- it is a mixture of the digits.
plt.imshow(digits, aspect="auto")

# %%
# I can sort by the labels, and show them grouped by digit.
digitsordered = digits[np.argsort(labels),:]
digits.shape

# %%
plt.imshow(digitsordered, aspect="auto")
